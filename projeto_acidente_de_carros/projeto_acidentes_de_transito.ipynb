# %%
# Importando a lib responsável por carregar e por explorar o DataFrame

import pandas as pd

# %%
# Carregando o arq na varável df_acidente_transito

df_acidente_transito = pd.read_csv("cat_acidentes.csv", sep=";")

# %%
# Visualizando as 10 primeiras linhas em df_acidente_transito

df_acidente_transito.head(10)
# Out:
#          data_extracao  predial1  queda_arr                 data  feridos  \
# 0  2024-06-01 01:33:30       0.0        0.0  2020-10-17 00:00:00        1
# 1  2024-06-01 01:33:30    6699.0        0.0  2019-01-01 00:00:00        1
# 2  2024-06-01 01:33:30     411.0        0.0  2019-01-01 00:00:00        1
# 3  2024-06-01 01:33:30    1500.0        0.0  2019-01-01 00:00:00        4
# 4  2024-06-01 01:33:30    8799.0        0.0  2019-01-01 00:00:00        5
# 5  2024-06-01 01:33:30     164.0        0.0  2019-01-01 00:00:00        1
# 6  2024-06-01 01:33:30     446.0        0.0  2019-01-02 00:00:00        1
# 7  2024-06-01 01:33:30     102.0        0.0  2019-01-02 00:00:00        0
# 8  2024-06-01 01:33:30    2380.0        0.0  2019-01-02 00:00:00        1
# 9  2024-06-01 01:33:30     298.0        0.0  2019-01-02 00:00:00        0
#
#    feridos_gr  mortes  morte_post  fatais  auto  ...     longitude  \
# 0           0       0           0       0     3  ...  0.000000e+00
# ...

# %%
# Instalando a lib folium que será responsável pela geração do mapa de calor
# !pip install folium
#
# Out:
# ...
#      ------------------------------------ 100.0/100.0 kB 955.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 83.9/83.9 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# Importação da lib folium e do HeatMap da folium.plugins responsáveis pela geração da imagem

import folium
from folium.plugins import HeatMap
